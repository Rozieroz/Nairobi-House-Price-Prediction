# %%
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# %%
def scrape_pages(start_page, end_page):
    base_url = 'https://www.buyrentkenya.com/houses-for-sale'
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
    }

    properties = []

    for page_num in range(start_page, end_page + 1):
        url = f'{base_url}?page={page_num}'
        print(f"Scraping page {page_num}: {url}")
        response = requests.get(url, headers=headers)

        if response.status_code != 200:
            print(f"Failed to retrieve the page. Status code: {response.status_code}")
            continue

        soup = BeautifulSoup(response.content, 'html.parser')
        listings = soup.find_all('div', class_='listing-card')

        for listing in listings:

            # --- Extract basic info from listing card ---
            title_tag = listing.find('h2')
            title = title_tag.get_text(strip=True) if title_tag else 'No title'

            price_tag = listing.find('a', class_='pointer-events-none z-10 no-underline')
            price = price_tag.get_text(strip=True) if price_tag else 'No price'

            location_tag = listing.find('p', class_='w-full truncate font-normal capitalize')
            location = location_tag.get_text(strip=True) if location_tag else 'No location'

            
            # --- extract each property link ---
            property_tag = listing.find('a', href=True)
            property_url = urljoin(base_url, property_tag['href']) if property_tag else None

            if not property_url:
                continue


            # Swiper slides extraction (bedrooms, bathrooms, size)
            swiper_div = listing.find('div', class_='scrollable-list')

            bedrooms = bathrooms = size = 'N/A'

            if swiper_div:
                slides = swiper_div.find_all('div', class_='swiper-slide')
                for slide in slides:
                    text = slide.get_text(strip=True)
                    if 'Bedroom' in text:
                        bedrooms = text
                    elif 'Bathroom' in text:
                        bathrooms = text
                    elif 'm²' in text or 'sq' in text.lower():
                        size = text

    # ===================================================
            # --- Visit the property detail page ---
            detail_response = requests.get(property_url, headers=headers)
            if detail_response.status_code != 200:
                print(f"Failed to load property page: {property_url}")
                continue


            detail_soup = BeautifulSoup(detail_response.content, "html.parser")

            created_at = "N/A"

            created_tag = detail_soup.find(
                string=lambda x: x and "Created At:" in x
            )

            if created_tag:
                created_at = created_tag.strip().replace("Created At:", "").strip()



            # --- Extract utilities and nearby facilities ---
            utilities =  []
            nearby = []

            sections = detail_soup.find_all("div", class_="px-3 py-3 even:bg-gray-50")
            for section in sections:
                title_span = section.find("span", class_="font-semibold")
                if not title_span:
                    continue

                section_name = title_span.get_text(strip=True).lower()
                items_div = section.find("div", class_="flex flex-wrap gap-3")
                if not items_div:
                    continue

                items = [span.get_text(strip=True) for span in items_div.find_all("span")]
                if "internal features" in section_name or "external features" in section_name:
                    utilities.extend(items)
                elif "nearby" in section_name:
                    nearby.extend(items)

    # ===================================================
            # --- Append property data ---
            properties.append({
                'Title': title,
                'Price': price,
                'Location': location,
                'Bedrooms': bedrooms,
                'Bathrooms': bathrooms,
                # 'Size': size_swiper,
                'Amenities': utilities,
                'Surroundings': nearby,
                'Created At': created_at
            })

            # --- Polite delay ---
            time.sleep(1)

        # Optional: stop once 500+ listings collected
        if len(properties) >= 500:
            print("Reached 500+ listings, stopping scrape.")
            break

    # Convert to DataFrame
    df = pd.DataFrame(properties)
    return df

# %%
df_all_pages = scrape_pages(start_page=1, end_page=2)
# Out:
# Scraping page 1: https://www.buyrentkenya.com/houses-for-sale?page=1
# Failed to retrieve the page. Status code: 404
# Scraping page 2: https://www.buyrentkenya.com/houses-for-sale?page=2

# %%
df_all_pages.head()
# Out:
#                                             Title            Price  \
# 0     5 Bed Townhouse with En Suite in Nyali Area   KSh 29,500,000
# 1      6 Bed Townhouse with En Suite in Lavington  KSh 160,000,000
# 2              4 Bed House with En Suite in Runda  KSh 155,040,000
# 3     5 Bed House with En Suite in Westlands Area   KSh 98,000,000
# 4  6 Bed Villa with En Suite at Loiyangalani Road   KSh 85,000,000
#
#                     Location    Bedrooms    Bathrooms  \
# 0          Nyali Area, Nyali  5 Bedrooms  5 Bathrooms
# 1                  Lavington  6 Bedrooms  7 Bathrooms
# 2           Runda, Westlands  4 Bedrooms  5 Bathrooms
# 3  Westlands Area, Westlands  5 Bedrooms  5 Bathrooms
# 4                  Lavington  6 Bedrooms  7 Bathrooms
#
#                                            Amenities  \
# 0  [Aircon, Alarm, Backup Generator, En Suite, Fi...
# 1  [Alarm, Backup Generator, En Suite, Fibre Inte...
# 2  [Alarm, Backup Generator, En Suite, Walk In Cl...
# 3  [Alarm, Backup Generator, En Suite, Fibre Inte...
# 4  [Aircon, Alarm, Backup Generator, En Suite, Fi...
#
#                                         Surroundings        Created At
# 0  [Bus Stop, Golf Course, Hospital, Scenic View,...  09 February 2026
# 1  [Bus Stop, Shopping Centre, Golf Course, Hospi...  06 February 2026
# 2  [Bus Stop, Shopping Centre, Hospital, Scenic V...   21 October 2025
# 3      [Bus Stop, Shopping Centre, Hospital, School]  17 February 2026
# 4  [Bus Stop, Hospital, Scenic View, School, Shop...  17 February 2026

# %%
from sqlalchemy import create_engine
import pandas as pd
import seaborn as sns
import datetime
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# get db credentials and load to db
database =os.getenv('database')
user = os.getenv('user')
password = os.getenv('password')
host = os.getenv('host')
port = os.getenv('port')

# Format: postgresql://username:password@host:port/database

engine = create_engine(f"postgresql://{user}:{password}@{host}:{port}/{database}")

# %%
query = ''' select * from houses."buy_rent"
'''

df_all_pages.to_sql("buy_rent", engine, schema="houses", if_exists="replace", index=False)
# Out:
# WARNING:  database "postgres" has a collation version mismatch
# DETAIL:  The database was created using collation version 2.41, but the operating system provides version 2.42.
# HINT:  Rebuild all objects in this database that use the default collation and run ALTER DATABASE postgres REFRESH COLLATION VERSION, or build PostgreSQL with the right library version.
# ---------------------------------------------------------------------------
# InvalidSchemaName                         Traceback (most recent call last)
# File ~/py312env/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File ~/py312env/lib/python3.12/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# InvalidSchemaName: schema "houses" does not exist
# LINE 2: CREATE TABLE houses.buy_rent (
#                      ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[24], line 4
#       1 query = ''' select * from houses."buy_rent"
#       2 '''
# ----> 4 df_all_pages.to_sql("buy_rent", engine, schema="houses", if_exists="replace", index=False)
#
# File ~/py312env/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/py312env/lib/python3.12/site-packages/pandas/core/generic.py:3106, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2908 """
#    2909 Write records stored in a DataFrame to a SQL database.
#    2910
#    (...)   3102 [(1,), (None,), (2,)]
#    3103 """  # noqa: E501
#    3104 from pandas.io import sql
# -> 3106 return sql.to_sql(
#    3107     self,
#    3108     name,
#    3109     con,
#    3110     schema=schema,
#    3111     if_exists=if_exists,
#    3112     index=index,
#    3113     index_label=index_label,
#    3114     chunksize=chunksize,
#    3115     dtype=dtype,
#    3116     method=method,
#    3117 )
#
# File ~/py312env/lib/python3.12/site-packages/pandas/io/sql.py:844, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     839     raise NotImplementedError(
#     840         "'frame' argument should be either a Series or a DataFrame"
#     841     )
#     843 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 844     return pandas_sql.to_sql(
#     845         frame,
#     846         name,
#     847         if_exists=if_exists,
#     848         index=index,
#     849         index_label=index_label,
#     850         schema=schema,
#     851         chunksize=chunksize,
#     852         dtype=dtype,
#     853         method=method,
#     854         engine=engine,
#     855         **engine_kwargs,
#     856     )
#
# File ~/py312env/lib/python3.12/site-packages/pandas/io/sql.py:2020, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1970 """
#    1971 Write records stored in a DataFrame to a SQL database.
#    1972
#    (...)   2016     Any additional kwargs are passed to the engine.
#    2017 """
#    2018 sql_engine = get_engine(engine)
# -> 2020 table = self.prep_table(
#    2021     frame=frame,
#    2022     name=name,
#    2023     if_exists=if_exists,
#    2024     index=index,
#    2025     index_label=index_label,
#    2026     schema=schema,
#    2027     dtype=dtype,
#    2028 )
#    2030 total_inserted = sql_engine.insert_records(
#    2031     table=table,
#    2032     con=self.con,
#    (...)   2039     **engine_kwargs,
#    2040 )
#    2042 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/py312env/lib/python3.12/site-packages/pandas/io/sql.py:1924, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1912             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1914 table = SQLTable(
#    1915     name,
#    1916     self,
#    (...)   1922     dtype=dtype,
#    1923 )
# -> 1924 table.create()
#    1925 return table
#
# File ~/py312env/lib/python3.12/site-packages/pandas/io/sql.py:997, in SQLTable.create(self)
#     995         raise ValueError(f"'{self.if_exists}' is not valid for if_exists")
#     996 else:
# --> 997     self._execute_create()
#
# File ~/py312env/lib/python3.12/site-packages/pandas/io/sql.py:983, in SQLTable._execute_create(self)
#     981 self.table = self.table.to_metadata(self.pd_sql.meta)
#     982 with self.pd_sql.run_transaction():
# --> 983     self.table.create(bind=self.pd_sql.con)
#
# File ~/py312env/lib/python3.12/site-packages/sqlalchemy/sql/schema.py:1293, in Table.create(self, bind, checkfirst)
#    1281 def create(self, bind: _CreateDropBind, checkfirst: bool = False) -> None:
#    1282     """Issue a ``CREATE`` statement for this
#    1283     :class:`_schema.Table`, using the given
#    1284     :class:`.Connection` or :class:`.Engine`
#    (...)   1290
#    1291     """
# -> 1293     bind._run_ddl_visitor(ddl.SchemaGenerator, self, checkfirst=checkfirst)
#
# File ~/py312env/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2447, in Connection._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    2435 def _run_ddl_visitor(
#    2436     self,
#    2437     visitorcallable: Type[Union[SchemaGenerator, SchemaDropper]],
#    2438     element: SchemaItem,
#    2439     **kwargs: Any,
#    2440 ) -> None:
#    2441     """run a DDL visitor.
#    2442
#    2443     This method is only here so that the MockConnection can change the
#    2444     options given to the visitor so that "checkfirst" is skipped.
#    2445
#    2446     """
# -> 2447     visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#
# File ~/py312env/lib/python3.12/site-packages/sqlalchemy/sql/visitors.py:671, in ExternalTraversal.traverse_single(self, obj, **kw)
#     669 meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     670 if meth:
# --> 671     return meth(obj, **kw)
#
# File ~/py312env/lib/python3.12/site-packages/sqlalchemy/sql/ddl.py:957, in SchemaGenerator.visit_table(self, table, create_ok, include_foreign_key_constraints, _is_metadata_operation)
#     948 if not self.dialect.supports_alter:
#     949     # e.g., don't omit any foreign key constraints
#     950     include_foreign_key_constraints = None
#     952 CreateTable(
#     953     table,
#     954     include_foreign_key_constraints=(
#     955         include_foreign_key_constraints
#     956     ),
# --> 957 )._invoke_with(self.connection)
#     959 if hasattr(table, "indexes"):
#     960     for index in table.indexes:
#
# File ~/py312env/lib/python3.12/site-packages/sqlalchemy/sql/ddl.py:315, in ExecutableDDLElement._invoke_with(self, bind)
#     313 def _invoke_with(self, bind):
#     314     if self._should_execute(self.target, bind):
# --> 315         return bind.execute(self)
#
# File ~/py312env/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File ~/py312env/lib/python3.12/site-packages/sqlalchemy/sql/ddl.py:181, in ExecutableDDLElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     178 def _execute_on_connection(
#     179     self, connection, distilled_params, execution_options
#     180 ):
# --> 181     return connection._execute_ddl(
#     182         self, distilled_params, execution_options
#     183     )
#
# File ~/py312env/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1528, in Connection._execute_ddl(self, ddl, distilled_parameters, execution_options)
#    1523 dialect = self.dialect
#    1525 compiled = ddl.compile(
#    1526     dialect=dialect, schema_translate_map=schema_translate_map
#    1527 )
# -> 1528 ret = self._execute_context(
#    1529     dialect,
#    1530     dialect.execution_ctx_cls._init_ddl,
#    1531     compiled,
#    1532     None,
#    1533     execution_options,
#    1534     compiled,
#    1535 )
#    1536 if self._has_events or self.engine._has_events:
#    1537     self.dispatch.after_execute(
#    1538         self,
#    1539         ddl,
#    (...)   1543         ret,
#    1544     )
#
# File ~/py312env/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843     return self._exec_insertmany_context(
#    1844         dialect,
#    1845         context,
#    1846     )
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File ~/py312env/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985     result = context._setup_result_proxy()
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File ~/py312env/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2343, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2341 elif should_wrap:
#    2342     assert sqlalchemy_exception is not None
# -> 2343     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2344 else:
#    2345     assert exc_info[1] is not None
#
# File ~/py312env/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1967                 break
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#    1974     self.dispatch.after_cursor_execute(
#    1975         self,
#    1976         cursor,
#    (...)   1980         context.executemany,
#    1981     )
#
# File ~/py312env/lib/python3.12/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.errors.InvalidSchemaName) schema "houses" does not exist
# LINE 2: CREATE TABLE houses.buy_rent (
#                      ^
#
# [SQL:
# CREATE TABLE houses.buy_rent (
# 	"Title" TEXT,
# 	"Price" TEXT,
# 	"Location" TEXT,
# 	"Bedrooms" TEXT,
# 	"Bathrooms" TEXT,
# 	"Size" TEXT
# )
#
# ]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# Load data from PostgreSQL into a DataFrame
df = pd.read_sql(query, engine)
df.head()
# Out:
#                                                Title            Price  \
# 0                               5 Bed House in Kyuna   KSh 90,000,000
# 1                 4 Bed House with En Suite at Ruiru   KSh 15,000,000
# 2         6 Bed House with En Suite in Garden Estate  KSh 130,000,000
# 3           4 Bed Townhouse with En Suite in South B   KSh 20,000,000
# 4  4 Bed Townhouse with Swimming Pool in Kiambu Road   KSh 45,000,000
#
#                   Location    Bedrooms    Bathrooms Size
# 0         Kyuna, Westlands  5 Bedrooms          N/A  N/A
# 1                    Ruiru  4 Bedrooms  6 Bathrooms  N/A
# 2  Garden Estate, Roysambu  6 Bedrooms  4 Bathrooms  N/A
# 3                  South B  4 Bedrooms  5 Bathrooms  N/A
# 4              Kiambu Road  4 Bedrooms  5 Bathrooms  N/A

# %%
df.isnull().sum()
# Out:
# Title        0
# Price        0
# Location     0
# Bedrooms     0
# Bathrooms    0
# Size         0
# dtype: int64

# %%
df.dtypes
# Out:
# Title        object
# Price        object
# Location     object
# Bedrooms     object
# Bathrooms    object
# Size         object
# dtype: object
